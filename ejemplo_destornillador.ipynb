# %% [markdown]
# ![Portada](https://www.canalgif.net/Gifs-animados/Herramientas/Destornilladores/Imagen-animada-Destornillador-13.gif)

# %% [markdown]
# ### Veamos como funciona nuestra herramienta

# %%
# Cargamos todo el conjunto de funciones que hemos creado en destornillador_ML
from destornillador_ML import *

# %%
# Leemos los datos del titanic
df_titanic = pd.read_csv("./data/titanic.csv")

# Mostrar las primeras filas del dataset
print("Dataset dftitanic cargado:")
print(df_titanic.head())
print(df_titanic.info())
# Out:
# Dataset dftitanic cargado:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ...

# %%
# Hacemos una breve limpieza del Dataset
df_titanic["age"]=df_titanic["age"].fillna(df_titanic["age"].mean())
df_titanic = df_titanic.drop(columns=["deck","parch"])
print(df_titanic.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   fare         891 non-null    float64
#  6   embarked     889 non-null    object
#  7   class        891 non-null    object
#  8   who          891 non-null    object
#  9   adult_male   891 non-null    bool
#  10  embark_town  889 non-null    object
#  11  alive        891 non-null    object
#  12  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(3), object(6)
# memory usage: 78.4+ KB
# None

# %% [markdown]
# ### Funcion: describe_df

# %%
# Cargamos la función describe_df y mostramos un breve resumen
resumen_dftitanic = describe_df(df_titanic)
print("\nResumen descriptivo de Titanic:")
print(resumen_dftitanic)
# Out:
# Resumen descriptivo de Titanic:
#                 type  null_percentage  unique_values  cardinality_percentage
# survived       int64         0.000000              2                0.224467
# pclass         int64         0.000000              3                0.336700
# sex           object         0.000000              2                0.224467
# age          float64         0.000000             89                9.988777
# sibsp          int64         0.000000              7                0.785634
# fare         float64         0.000000            248               27.833895
# embarked      object         0.224467              3                0.336700
# class         object         0.000000              3                0.336700
# who           object         0.000000              3                0.336700
# adult_male      bool         0.000000              2                0.224467
# embark_town   object         0.224467              3                0.336700
# ...

# %% [markdown]
# ### Funcion: tipifica_variables

# %%
# Hallamos la función tipifica_variables que clasifica el tipo de las variables que tiene el df
umbral_categoria = 5
umbral_continua = 70.0
clasificacion_dftitanic = tipifica_variables(df_titanic, umbral_categoria, umbral_continua)
print("\nClasificación de las variables de Titanic:")
print(clasificacion_dftitanic)
# Out:
# Clasificación de las variables de Titanic:
#    nombre_variable      tipo_sugerido
# 0         survived            Binaria
# 1           pclass         Categórica
# 2              sex            Binaria
# 3              age  Numerica Discreta
# 4            sibsp  Numerica Discreta
# 5             fare  Numerica Discreta
# 6         embarked         Categórica
# 7            class         Categórica
# 8              who         Categórica
# 9       adult_male            Binaria
# 10     embark_town         Categórica
# 11           alive            Binaria
# 12           alone            Binaria

# %% [markdown]
# ### Funcion: get_features_num_regression

# %%
# Previamente, definimos target_col de este ejemplo
target_col="survived"

# %%
# Hallamos la función que muestra las columnas numéricas del df
resultado = get_features_num_regression(df_titanic,target_col , 0, 0.05)
print("Columnas numéricas significativas:", resultado)
# Out:
# Columnas numéricas significativas: ['pclass', 'age', 'fare']

# %% [markdown]
# ### Funcion: plot_features_num_regression

# %%
# Graficamos las columnas numéricas
resultado = plot_features_num_regression(df_titanic,  target_col, columns=['pclass', 'age', 'fare'], umbral_corr=0, pvalue=None)

print("Columnas categóricas significativas:", resultado)
# Out:
# Columnas categóricas significativas: ['pclass', 'age', 'fare']

# %% [markdown]
# ### Funcion: get_features_cat_regression

# %%
# Hallamos las columnas numéricas
resultado_num = get_features_cat_regression(df_titanic, target_col, pvalue=0.05)
print("Columnas categóricas significativas:", resultado_num)
# Out:
# Columnas categóricas significativas: {'pclass': 5.510281000643817e-23, 'sex': 1.4060661308802591e-69, 'sibsp': 2.0114415916142427e-07, 'embarked': 5.483343931955073e-06, 'class': 5.510281000643817e-23, 'who': 8.998259162091177e-74, 'adult_male': 8.998259162091177e-74, 'embark_town': 5.483343931955073e-06, 'alive': 0.0, 'alone': 9.009490179329494e-10}

# %% [markdown]
# ### Funcion: plot_features_cat_regression

# %%
# Llamar a la función con histogramas activados
resultado = plot_features_cat_regression(df_titanic, target_col, columns=[ 'pclass', 'sex', 'sibsp','embarked', 'class', 'who','adult_male', 'embark_town'], pvalue=0.05, with_individual_plot=True, bins=10)

print("Columnas categóricas significativas:", resultado)
# Out:
# Aviso: Se eliminaron 2 filas debido a valores nulos en las columnas seleccionadas.
# Columnas categóricas significativas: {'pclass': 6.3447980272512585e-24, 'sex': 6.682012140612383e-69, 'sibsp': 9.601456600644424e-07, 'embarked': 1.514339014290716e-06, 'class': 6.3447980272512585e-24, 'who': 5.2120851830004226e-74, 'adult_male': 3.992354998234265e-73, 'embark_town': 1.514339014290716e-06}
